# %%
import pandas as pd

# %%
df = pd.read_csv("../sample_filings_0.csv")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#         FILER_ID FREPORT_ID TRANSACTION_CODE  E_YEAR  T3_TRID    DATE1_10  \
# 0         C19814          K                A    2017      429  02/22/2017
# 1         A07277          A                A    2012     6169  07/27/2012
# 2         A13501          K                C    2014    12406  03/24/2014
# 3         A13510          E                C    2004     6504  10/15/2004
# 4         A04177          K                C    2004     4835  07/11/2004
# ...          ...        ...              ...     ...      ...         ...
# 8951284   C20547          K                B    2014     6220  02/24/2014
# 8951285   C36100          C                B    2008     5696  09/15/2008
# 8951286   A11696          J                C    2015        1  11/30/2014
# 8951287   A11506          J                A    2003     4164  11/29/2002
# 8951288   A29755          K                A    2007     5745  04/16/2007
#
#         DATE2_12 CONTRIB_CODE_20 CONTRIB_TYPE_CODE_25  \
# ...

# %%
df_amount2 = df[~df.AMOUNT2_72.isna()]

# %%
df_amount2[df_amount2.AMOUNT2_72.str.len() > 15]
# Out:
#         FILER_ID FREPORT_ID TRANSACTION_CODE  E_YEAR  T3_TRID    DATE1_10  \
# 4292735   A11225          D                D    2004     6013  09/19/2004
# 5051275   A11225          D                D    2004     6011  07/26/2004
# 6589530   A11225          D                D    2004     6012  09/10/2004
# 7089447   C46662          K                D    2009     5717  05/21/2009
# 8450122   A11225          D                D    2004     6010  07/26/2004
#
#         DATE2_12 CONTRIB_CODE_20 CONTRIB_TYPE_CODE_25 CORP_30 FIRST_NAME_40  \
# 4292735      NaN             IND                    3     NaN         HOWIE
# 5051275      NaN             IND                    3     NaN         HOWIE
# 6589530      NaN             IND                    3     NaN         HOWIE
# 7089447      NaN            CORP                    1     NaN      HAIR OF"
# 8450122      NaN             IND                    3     NaN         HOWIE
#
# ...

# %%
df.loc[1873]
# Out:
# FILER_ID                             A00897
# FREPORT_ID                                F
# TRANSACTION_CODE                          A
# E_YEAR                                 2015
# T3_TRID                           453130000
# DATE1_10                         11/24/2015
# DATE2_12                                NaN
# CONTRIB_CODE_20                           A
# CONTRIB_TYPE_CODE_25                    NaN
# CORP_30                                 NaN
# FIRST_NAME_40                        THOMAS
# MID_INIT_42                               R
# LAST_NAME_44                         FRIEND
# ADDR_1_50                  1022 DELAWARE DR
# CITY_52                           MATAMORAS
# STATE_54                                 PA
# ZIP_56                                18336
# CHECK_NO_60                             OTH
# CHECK_DATE_62                           NaN
# AMOUNT_70                              8.36
# AMOUNT2_72                              NaN
# ...

# %%
df_filers = pd.read_csv("sample_filers.csv")

# %%
df_filers
# Out:
#       FILER_ID                        FILER_NAME FILER_TYPE    STATUS  \
# 0       C21680  GENEVA CITY DEMOCRATIC COMMITTEE  COMMITTEE    ACTIVE
# 1       C53256            WILLIAM W. MCGREEVY JR  CANDIDATE  INACTIVE
# 2       C35430                    GLENN SCOFIELD  CANDIDATE    ACTIVE
# 3       A05962                   NORA  FELICIANO  CANDIDATE  INACTIVE
# 4       C33137      FRIENDS OF JAMES A.W. MCLEOD  COMMITTEE  INACTIVE
# ...        ...                               ...        ...       ...
# 11405   C08673                AMBRUOSO FOR MAYOR  COMMITTEE    ACTIVE
# 11406   A23690                DAWN MARIE JIMENEZ  CANDIDATE  INACTIVE
# 11407   C09568                 LAUREN TRAPANOTTO  CANDIDATE    ACTIVE
# 11408   A11336      FRIENDS TO ELECT CATHY YOUNG  COMMITTEE  INACTIVE
# 11409   A12312           FRIENDS OF EILEEN HOTHO  COMMITTEE  INACTIVE
#
#       COMMITTEE_TYPE  OFFICE  DISTRICT TREAS_FIRST_NAME TREAS_LAST_NAME  \
# ...

# %%
df_filers.loc[:,'OFFICE'] = df_filers['OFFICE'].astype('int', errors='ignore')

# %%
df_filers = df_filers.astype({'OFFICE':'Int64'},errors='ignore')

# %%
df_filers['OFFICE']
# Out:
# 0        NaN
# 1         53
# 2         39
# 3         11
# 4         57
#         ...
# 11405     22
# 11406      9
# 11407    NaN
# 11408     12
# 11409     12
# Name: OFFICE, Length: 11410, dtype: Int64
