# %% [markdown]
# # Visualize Results of Matching Runs from CORP Runs with extra processing 1

# %% [markdown]
# ## Import in data from runs

# %%
import pandas as pd

# %%
data_df = pd.read_csv('all_corp_runs_12_08.csv')

# %%
data_df['settings_file'].unique()
# Out:
# array(['dedupe_extension/settings_0', 'dedupe_extension/settings_1',
#        'dedupe_extension/settings_2', 'dedupe_extension/settings_3',
#        'dedupe_extension/settings_4',
#        'dedupe_extension/settings/settings_0',
#        'dedupe_extension/settings/settings_1',
#        'dedupe_extension/settings/settings_2',
#        'dedupe_extension/settings/settings_3',
#        'dedupe_extension/settings/settings_4'], dtype=object)

# %%
data_df
# Out:
#     run_id completed                                         predicates  \
# 0       12  11/29/20  (ExistsPredicate: (Exists, zip), SimplePredica...
# 1       13  11/29/20  (SimplePredicate: (sameFiveCharStartPredicate,...
# 2       14  11/29/20  (SimplePredicate: (doubleMetaphone, state), Si...
# 3       15  11/29/20  (ExistsPredicate: (Exists, city), SimplePredic...
# 4       16  11/29/20  (SimplePredicate: (sameSevenCharStartPredicate...
# 5       17  11/29/20  (ExistsPredicate: (Exists, zip), SimplePredica...
# 6       18  11/29/20  (SimplePredicate: (sameFiveCharStartPredicate,...
# 7       19  11/29/20  (SimplePredicate: (doubleMetaphone, state), Si...
# 8       20  11/29/20  (ExistsPredicate: (Exists, city), SimplePredic...
# 9       21  11/29/20  (SimplePredicate: (sameSevenCharStartPredicate...
# 10      22  11/29/20  (ExistsPredicate: (Exists, zip), SimplePredica...
# 11      23  11/29/20  (SimplePredicate: (sameFiveCharStartPredicate,...
# 12      24  11/29/20  (SimplePredicate: (doubleMetaphone, state), Si...
# 13      25  11/29/20  (ExistsPredicate: (Exists, city), SimplePredic...
# 14      26  11/29/20  (SimplePredicate: (sameSevenCharStartPredicate...
# 15      27  11/29/20  (ExistsPredicate: (Exists, zip), SimplePredica...
# 16      28  11/29/20  (SimplePredicate: (sameFiveCharStartPredicate,...
# 17      29  11/29/20  (SimplePredicate: (doubleMetaphone, state), Si...
# 18      30  11/29/20  (ExistsPredicate: (Exists, city), SimplePredic...
# 19      31  11/30/20  (SimplePredicate: (sameSevenCharStartPredicate...
# 20      32  11/30/20  (ExistsPredicate: (Exists, zip), SimplePredica...
# 21      33  11/30/20  (SimplePredicate: (sameFiveCharStartPredicate,...
# 22      34  11/30/20  (SimplePredicate: (doubleMetaphone, state), Si...
# 23      35  11/30/20  (ExistsPredicate: (Exists, city), SimplePredic...
# 24      36  11/30/20  (SimplePredicate: (sameSevenCharStartPredicate...
# 25      97   12/7/20  (ExistsPredicate: (Exists, zip), SimplePredica...
# 26      98   12/7/20  (SimplePredicate: (sameFiveCharStartPredicate,...
# 27      99   12/7/20  (SimplePredicate: (doubleMetaphone, state), Si...
# 28     100   12/7/20  (ExistsPredicate: (Exists, city), SimplePredic...
# 29     101   12/7/20  (SimplePredicate: (sameSevenCharStartPredicate...
# 30     102   12/7/20  (ExistsPredicate: (Exists, zip), SimplePredica...
# 31     103   12/7/20  (SimplePredicate: (sameFiveCharStartPredicate,...
# 32     104   12/7/20  (SimplePredicate: (doubleMetaphone, state), Si...
# 33     105   12/7/20  (ExistsPredicate: (Exists, city), SimplePredic...
# 34     106   12/7/20  (SimplePredicate: (sameSevenCharStartPredicate...
# 35     107   12/7/20  (ExistsPredicate: (Exists, zip), SimplePredica...
# 36     108   12/7/20  (SimplePredicate: (sameFiveCharStartPredicate,...
# 37     109   12/7/20  (SimplePredicate: (doubleMetaphone, state), Si...
# 38     110   12/7/20  (ExistsPredicate: (Exists, city), SimplePredic...
# 39     111   12/7/20  (SimplePredicate: (sameSevenCharStartPredicate...
# 40     112   12/8/20  (ExistsPredicate: (Exists, zip), SimplePredica...
# 41     113   12/8/20  (SimplePredicate: (sameFiveCharStartPredicate,...
# 42     114   12/8/20  (SimplePredicate: (doubleMetaphone, state), Si...
# 43     115   12/8/20  (ExistsPredicate: (Exists, city), SimplePredic...
# 44     116   12/8/20  (SimplePredicate: (sameSevenCharStartPredicate...
# 45     117   12/8/20  (ExistsPredicate: (Exists, zip), SimplePredica...
# 46     118   12/8/20  (SimplePredicate: (sameFiveCharStartPredicate,...
# 47     119   12/8/20  (SimplePredicate: (doubleMetaphone, state), Si...
# 48     120   12/8/20  (ExistsPredicate: (Exists, city), SimplePredic...
# 49     121   12/8/20  (SimplePredicate: (sameSevenCharStartPredicate...
#
#     total_clusters  avg_cluster_size  biggest_cluster_size  \
# 0             4094          3.645335                    73
# 1             4135          3.217896                    92
# 2             4189          3.645261                    83
# 3             4172          3.652685                    75
# 4             4108          3.634615                    97
# 5             8275          3.959033                   141
# 6             8635          3.422698                   171
# 7             8306          4.008668                   172
# 8             8355          3.981448                   157
# 9             8286          3.949312                   199
# 10           12144          4.179018                   196
# 11           12981          3.544796                   222
# 12           12241          4.207091                   219
# 13           12236          4.202926                   202
# 14           12099          4.189685                   249
# 15           15681          4.379440                   235
# 16           16838          3.728887                   293
# 17           16246          4.288686                   278
# 18           16092          4.323515                   252
# 19           15850          4.336719                   320
# 20           19102          4.491886                   292
# 21           20720          3.796863                   331
# 22           20004          4.304739                   334
# 23           19688          4.392168                   299
# 24           19162          4.486014                   382
# 25            4117          3.635657                    73
# 26            4150          3.209157                    93
# 27            4237          3.625207                    82
# 28            4209          3.638156                    74
# 29            4124          3.631911                    98
# 30            8378          3.938052                   141
# 31            8704          3.410501                   171
# 32            8437          3.981510                   173
# 33            8482          3.955671                   157
# 34            8384          3.928316                   199
# 35           12306          4.153096                   197
# 36           13122          3.524082                   224
# 37           12456          4.172688                   220
# 38           12451          4.168661                   203
# 39           12254          4.164110                   251
# 40           15901          4.351236                   236
# 41           16973          3.716962                   293
# 42           16529          4.255914                   279
# 43           16366          4.291641                   252
# 44           16076          4.306668                   320
# 45           19385          4.458963                   288
# 46           20938          3.777964                   329
# 47           20304          4.274773                   336
# 48           20021          4.357175                   297
# 49           19451          4.449488                   382
#
#                             biggest_cluster  total_donors donor_type  \
# 0                         unitemized:124539         30516       CORP
# 1                         unitemized:124539         30516       CORP
# 2                         unitemized:124539         30516       CORP
# 3                         unitemized:124539         30516       CORP
# 4                         unitemized:124539         30516       CORP
# 5                         unitemized:281958         57603       CORP
# 6              unitemized unitemized:227955         57603       CORP
# 7              unitemized unitemized:227955         57603       CORP
# 8                         unitemized:281959         57603       CORP
# 9              unitemized unitemized:227955         57603       CORP
# 10                        unitemized:396629         82661       CORP
# 11                        unitemized:319282         82661       CORP
# 12                        unitemized:319282         82661       CORP
# 13                       unitemitzed:396626         82661       CORP
# 14                        unitemized:319282         82661       CORP
# 15             unitemized unitemized:404309        106745       CORP
# 16             unitemized unitemized:404309        106745       CORP
# 17             unitemized unitemized:404309        106745       CORP
# 18             unitemized unitemized:404309        106745       CORP
# 19             unitemized unitemized:404309        106745       CORP
# 20                        unitemized:483508        129832       CORP
# 21             unitemized unitemized:483507        129832       CORP
# 22             unitemized unitemized:483507        129832       CORP
# 23                        unitemized:483508        129832       CORP
# 24             unitemized unitemized:483507        129832       CORP
# 25   unitemized cash unitemized cash:118660         31046       CORP
# 26   unitemized cash unitemized cash:118660         31046       CORP
# 27             unitemized unitemized:118664         31046       CORP
# 28                        unitemized:153147         31046       CORP
# 29   unitemized cash unitemized cash:118660         31046       CORP
# 30                        unitemized:281958         58646       CORP
# 31             unitemized unitemized:217325         58646       CORP
# 32             unitemized unitemized:217325         58646       CORP
# 33                        unitemized:281959         58646       CORP
# 34             unitemized unitemized:217325         58646       CORP
# 35             unitemized unitemized:304359         84189       CORP
# 36             unitemized unitemized:304359         84189       CORP
# 37             unitemized unitemized:304359         84189       CORP
# 38             unitemized unitemized:304359         84189       CORP
# 39             unitemized unitemized:304359         84189       CORP
# 40   unitemized cash unitemized cash:385521        108644       CORP
# 41   unitemized cash unitemized cash:385521        108644       CORP
# 42             unitemized unitemized:385537        108644       CORP
# 43             unitemized unitemized:404309        108644       CORP
# 44   unitemized cash unitemized cash:385521        108644       CORP
# 45   unitemized cash unitemized cash:460999        132169       CORP
# 46             unitemized unitemized:461013        132169       CORP
# 47  unitemized unitemized unitemized:461008        132169       CORP
# 48                       unitemitzed:605045        132169       CORP
# 49   unitemized cash unitemized cash:460999        132169       CORP
#
#     total_run_time  donor_cluster_ratio                         settings_file  \
# 0      1204.672363             7.453835           dedupe_extension/settings_0
# 1        60.673950             7.379927           dedupe_extension/settings_1
# 2       114.452933             7.284794           dedupe_extension/settings_2
# 3       110.346118             7.314477           dedupe_extension/settings_3
# 4      1008.662108             7.428432           dedupe_extension/settings_4
# 5      3367.898362             6.961088           dedupe_extension/settings_0
# 6       143.204981             6.670874           dedupe_extension/settings_1
# 7       753.902161             6.935107           dedupe_extension/settings_2
# 8       823.206980             6.894434           dedupe_extension/settings_3
# 9      2512.465557             6.951846           dedupe_extension/settings_4
# 10     6591.080133             6.806736           dedupe_extension/settings_0
# 11      270.608700             6.367845           dedupe_extension/settings_1
# 12     1885.442988             6.752798           dedupe_extension/settings_2
# 13     2170.559486             6.755557           dedupe_extension/settings_3
# 14     5078.115249             6.832052           dedupe_extension/settings_4
# 15     8359.066649             6.807283           dedupe_extension/settings_0
# 16      351.151658             6.339530           dedupe_extension/settings_1
# 17     1884.292302             6.570540           dedupe_extension/settings_2
# 18     1812.282960             6.633420           dedupe_extension/settings_3
# 19     4726.857347             6.734700           dedupe_extension/settings_4
# 20     9564.475617             6.796775           dedupe_extension/settings_0
# 21      474.204515             6.266023           dedupe_extension/settings_1
# 22     1717.644825             6.490302           dedupe_extension/settings_2
# 23     1585.336788             6.594474           dedupe_extension/settings_3
# 24     7250.427141             6.775493           dedupe_extension/settings_4
# 25     1273.578333             7.540928  dedupe_extension/settings/settings_0
# 26       61.565933             7.480964  dedupe_extension/settings/settings_1
# 27      117.979492             7.327354  dedupe_extension/settings/settings_2
# 28      113.463920             7.376099  dedupe_extension/settings/settings_3
# 29     1051.636595             7.528128  dedupe_extension/settings/settings_4
# 30     3526.952108             7.000000  dedupe_extension/settings/settings_0
# 31      144.846920             6.737822  dedupe_extension/settings/settings_1
# 32      815.679815             6.951049  dedupe_extension/settings/settings_2
# 33      847.887402             6.914171  dedupe_extension/settings/settings_3
# 34     2577.783043             6.994990  dedupe_extension/settings/settings_4
# 35     7569.769692             6.841297  dedupe_extension/settings/settings_0
# 36      305.802510             6.415866  dedupe_extension/settings/settings_1
# 37     2763.687933             6.758911  dedupe_extension/settings/settings_2
# 38     3445.996198             6.761626  dedupe_extension/settings/settings_3
# 39     5946.434619             6.870328  dedupe_extension/settings/settings_4
# 40     8901.638849             6.832526  dedupe_extension/settings/settings_0
# 41      354.423938             6.400990  dedupe_extension/settings/settings_1
# 42     2029.402033             6.572932  dedupe_extension/settings/settings_2
# 43     1848.997320             6.638397  dedupe_extension/settings/settings_3
# 44     5324.073583             6.758149  dedupe_extension/settings/settings_4
# 45    10127.641730             6.818107  dedupe_extension/settings/settings_0
# 46      487.036657             6.312399  dedupe_extension/settings/settings_1
# 47     1854.418755             6.509506  dedupe_extension/settings/settings_2
# 48     1660.639859             6.601518  dedupe_extension/settings/settings_3
# 49     7748.386208             6.794972  dedupe_extension/settings/settings_4
#
#    settings_file_shortened  processing_level  settings_num
# 0               settings_0                 0             5
# 1               settings_1                 0             6
# 2               settings_2                 0             7
# 3               settings_3                 0             8
# 4               settings_4                 0             9
# 5               settings_0                 0             5
# 6               settings_1                 0             6
# 7               settings_2                 0             7
# 8               settings_3                 0             8
# 9               settings_4                 0             9
# 10              settings_0                 0             5
# 11              settings_1                 0             6
# 12              settings_2                 0             7
# 13              settings_3                 0             8
# 14              settings_4                 0             9
# 15              settings_0                 0             5
# 16              settings_1                 0             6
# 17              settings_2                 0             7
# 18              settings_3                 0             8
# 19              settings_4                 0             9
# 20              settings_0                 0             5
# 21              settings_1                 0             6
# 22              settings_2                 0             7
# 23              settings_3                 0             8
# 24              settings_4                 0             9
# 25              settings_0                 1             0
# 26              settings_1                 1             1
# 27              settings_2                 1             2
# 28              settings_3                 1             3
# 29              settings_4                 1             4
# 30              settings_0                 1             0
# 31              settings_1                 1             1
# 32              settings_2                 1             2
# 33              settings_3                 1             3
# 34              settings_4                 1             4
# 35              settings_0                 1             0
# 36              settings_1                 1             1
# 37              settings_2                 1             2
# 38              settings_3                 1             3
# 39              settings_4                 1             4
# 40              settings_0                 1             0
# 41              settings_1                 1             1
# 42              settings_2                 1             2
# 43              settings_3                 1             3
# 44              settings_4                 1             4
# 45              settings_0                 1             0
# 46              settings_1                 1             1
# 47              settings_2                 1             2
# 48              settings_3                 1             3
# 49              settings_4                 1             4

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
from matplotlib import cm
from numpy import linspace

# %%
files = [['dedupe_extension/settings_0','settings_0 orig'],
         ['dedupe_extension/settings_1','settings_1 orig'],
         ['dedupe_extension/settings_2','settings_2 orig'],
         ['dedupe_extension/settings_3','settings_3 orig'],
         ['dedupe_extension/settings_4', 'settings_4 orig'],
         ['dedupe_extension/settings/settings_4','settings_4 extra'],
         ['dedupe_extension/settings/settings_3','settings_3 extra'],
         ['dedupe_extension/settings/settings_2','settings_2 extra'],
         ['dedupe_extension/settings/settings_1','settings_1 extra'],
         ['dedupe_extension/settings/settings_0','settings_0 extra']]

# %%
start = 0.0
stop = 1.0
number_of_lines= len(files)
cm_subsection = linspace(start, stop, number_of_lines) 
colors = [ cm.bwr(x) for x in cm_subsection ]

# %%
ratio_sets = []
for i, file in enumerate(files):
    data_cut = data_df[data_df['settings_file'] == file[0]].sort_values('total_donors')
    color = colors[i]
    ratio_sets.append([data_cut['total_donors'].values, data_cut['donor_cluster_ratio'].values, file[1], color])

# %%
ratio_sets
# Out:
# [[array([ 30516,  57603,  82661, 106745, 129832]),
#   array([7.45383488, 6.96108761, 6.80673584, 6.8072827 , 6.79677521]),
#   'settings_0 orig',
#   (0.0, 0.0, 1.0, 1.0)],
#  [array([ 30516,  57603,  82661, 106745, 129832]),
#   array([7.37992745, 6.67087435, 6.36784531, 6.33952963, 6.26602317]),
#   'settings_1 orig',
#   (0.2196078431372549, 0.2196078431372549, 1.0, 1.0)],
#  [array([ 30516,  57603,  82661, 106745, 129832]),
#   array([7.28479351, 6.93510715, 6.75279797, 6.57054044, 6.49030194]),
#   'settings_2 orig',
#   (0.4392156862745098, 0.4392156862745098, 1.0, 1.0)],
#  [array([ 30516,  57603,  82661, 106745, 129832]),
#   array([7.31447747, 6.89443447, 6.75555737, 6.63342033, 6.59447379]),
#   'settings_3 orig',
#   (0.6666666666666666, 0.6666666666666666, 1.0, 1.0)],
#  [array([ 30516,  57603,  82661, 106745, 129832]),
#   array([7.42843233, 6.95184649, 6.83205224, 6.73470032, 6.77549316]),
#   'settings_4 orig',
#   (0.8862745098039215, 0.8862745098039215, 1.0, 1.0)],
#  [array([ 31046,  58646,  84189, 108644, 132169]),
#   array([7.52812803, 6.99499046, 6.87032806, 6.75814879, 6.79497198]),
#   'settings_4 extra',
#   (1.0, 0.8862745098039215, 0.8862745098039215, 1.0)],
#  [array([ 31046,  58646,  84189, 108644, 132169]),
#   array([7.37609884, 6.91417119, 6.76162557, 6.63839668, 6.60151841]),
#   'settings_3 extra',
#   (1.0, 0.6666666666666667, 0.6666666666666667, 1.0)],
#  [array([ 31046,  58646,  84189, 108644, 132169]),
#   array([7.32735426, 6.95104895, 6.75891137, 6.57293242, 6.50950552]),
#   'settings_2 extra',
#   (1.0, 0.4392156862745098, 0.4392156862745098, 1.0)],
#  [array([ 31046,  58646,  84189, 108644, 132169]),
#   array([7.48096385, 6.73782169, 6.41586648, 6.40098981, 6.31239851]),
#   'settings_1 extra',
#   (1.0, 0.2196078431372549, 0.2196078431372549, 1.0)],
#  [array([ 31046,  58646,  84189, 108644, 132169]),
#   array([7.54092786, 7.        , 6.84129693, 6.83252626, 6.81810678]),
#   'settings_0 extra',
#   (1.0, 0.0, 0.0, 1.0)]]

# %%
plt.figure(figsize=(8,8))
for s in ratio_sets:
    plt.plot(s[0],s[1], ms=6, marker='.', label=s[2], color=s[3])
plt.xlabel('total donors')
plt.ylabel('donor to cluster ratio')
plt.legend()

# %%
avg_size_sets = []
for i, file in enumerate(files):
    data_cut = data_df[data_df['settings_file'] == file[0]].sort_values('total_donors')
    color = colors[i]
    avg_size_sets.append([data_cut['total_donors'].values, data_cut['avg_cluster_size'].values, file[1], color])

# %%
plt.figure(figsize=(8,8))
for s in avg_size_sets:
    plt.plot(s[0],s[1], ms=6, marker='.', label=s[2], color=s[3])
plt.xlabel('total donors')
plt.ylabel('avg cluster size')
plt.legend()

# %%
biggest_size_sets = []
for i,file in enumerate(files):
    data_cut = data_df[data_df['settings_file'] == file[0]].sort_values('total_donors')
    color = colors[i]
    biggest_size_sets.append([data_cut['total_donors'].values, data_cut['biggest_cluster_size'].values, file[1], color])

# %%
plt.figure(figsize=(8,8))
for s in biggest_size_sets:
    plt.plot(s[0],s[1], ms=6, marker='.', label=s[2], color=s[3])
plt.xlabel('total donors')
plt.ylabel('biggest cluster size')
plt.legend()

# %%
total_clusters_sets = []
for i,file in enumerate(files):
    data_cut = data_df[data_df['settings_file'] == file[0]].sort_values('total_donors')
    color = colors[i]
    total_clusters_sets.append([data_cut['total_donors'].values, data_cut['total_clusters'].values, file[0], color])

# %%
plt.figure(figsize=(8,8))
for s in total_clusters_sets:
    plt.plot(s[0],s[1], ms=6, marker='.', label=s[2], color=s[3])
plt.xlabel('total donors')
plt.ylabel('total clusters')
plt.legend()
